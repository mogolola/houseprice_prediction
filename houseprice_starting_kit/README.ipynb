# %% [markdown]
# # Introduction
#
# Houses prices is a small standard Regression problem, the data set was token from a kaggle competition, formatted in the AutoML format.

# %%
model_dir = 'sample_code_submission/'          
problem_dir = 'ingestion_program/'  
score_dir = 'scoring_program/'
# %matplotlib inline
import numpy as np
import pandas as pd
import pylab as plt
from sys import path; path.append(model_dir); path.append(problem_dir); path.append(score_dir); 
import seaborn as sns; sns.set()

# %% [markdown]
# # Step 1: Exploratory data analysis
#
# We provide sample_data with the starting kit, but to prepare your submission, you must fetch the public_data from the challenge website and point to it.

# %%
datadir = 'sample_data/'             
basename = 'houseprice'
# !ls $datadir*
# Out:
# sample_data/houseprice_feat.name      sample_data/houseprice_train.data
# sample_data/houseprice_label.name     sample_data/houseprice_train.solution
# sample_data/houseprice_test.data      sample_data/houseprice_valid.data
# sample_data/houseprice_test.solution  sample_data/houseprice_valid.solution

# %%
# We read data as Panda data frames
feat_name = pd.read_csv(datadir+basename + '_feat.name', header=None)
label_name = pd.read_csv(datadir+basename + '_label.name', header=None)


X = pd.read_csv(datadir+basename + '_train.data', sep=' ', names = np.ravel(feat_name))
Y = pd.read_csv(datadir+ basename + '_train.solution', sep=' ', names = np.ravel(label_name))



X_valid = pd.read_csv(datadir+basename + '_valid.data', sep=' ', names = np.ravel(feat_name))
Y_valid = pd.read_csv(datadir+ basename + '_valid.solution', sep=' ', names = np.ravel(label_name))
X_test = pd.read_csv(datadir+basename + '_test.data', sep=' ', names = np.ravel(feat_name))
Y_test = pd.read_csv(datadir+ basename + '_test.solution', sep=' ', names = np.ravel(label_name))



X['waterfront'] = X['waterfront'].astype('category',ordered=True)
X['view'] = X['view'].astype('category',ordered=True)
X['condition'] = X['condition'].astype('category',ordered=True)
X['grade'] = X['grade'].astype('category',ordered=False)


X_valid['waterfront'] = X_valid['waterfront'].astype('category',ordered=True)
X_valid['view'] = X_valid['view'].astype('category',ordered=True)
X_valid['condition'] = X_valid['condition'].astype('category',ordered=True)
X_valid['grade'] = X_valid['grade'].astype('category',ordered=False)


X_test['waterfront'] = X_test['waterfront'].astype('category',ordered=True)
X_test['view'] = X_test['view'].astype('category',ordered=True)
X_test['condition'] = X_test['condition'].astype('category',ordered=True)
X_test['grade'] = X_test['grade'].astype('category',ordered=False)

[patnum, featnum] = X.shape
[patnum2, classnum] = Y.shape
assert(patnum==patnum2)
print 'Number of examples = %d' % patnum
print 'Number of features = %d' % featnum
print 'Number of variables to predict = %d' % classnum
# Out:
# Number of examples = 100
# Number of features = 18
# Number of variables to predict = 1
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:18: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:19: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:20: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:21: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:24: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:25: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:26: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:27: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:30: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:31: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:32: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:33: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead

# %%
X.describe()
# Out:
#          bedrooms   bathrooms  sqft_living       sqft_lot      floors  \
# count  100.000000  100.000000   100.000000     100.000000  100.000000
# mean     3.270000    1.800000  2109.030000   14252.370000    1.530000
# std      0.802207    0.778499   965.116306   35109.687847    0.610597
# min      2.000000    0.000000   590.000000     987.000000    1.000000
# 25%      3.000000    1.000000  1417.500000    4658.250000    1.000000
# 50%      3.000000    2.000000  1940.000000    7054.000000    1.000000
# 75%      4.000000    2.000000  2567.500000   11995.500000    2.000000
# max      5.000000    4.000000  6330.000000  308080.000000    3.000000
#
#         sqft_above  sqft_basement     yr_built  yr_renovated       zipcode  \
# count   100.000000     100.000000   100.000000    100.000000    100.000000
# mean   1842.120000     266.910000  1970.800000    120.080000  98086.130000
# std     825.823975     421.738899    32.413365    477.691284     53.207551
# min     590.000000       0.000000  1905.000000      0.000000  98001.000000
# 25%    1200.000000       0.000000  1947.000000      0.000000  98041.500000
# 50%    1625.000000       0.000000  1975.500000      0.000000  98097.000000
# 75%    2295.000000     465.000000  2000.000000      0.000000  98122.000000
# max    4900.000000    1510.000000  2014.000000   2013.000000  98199.000000
#
#          lat        long  sqft_living15     sqft_lot15
# count  100.0  100.000000     100.000000     100.000000
# mean    47.0 -121.930000    2015.720000   13273.380000
# std      0.0    0.256432     624.246132   33179.528865
# min     47.0 -122.000000    1030.000000    1230.000000
# 25%     47.0 -122.000000    1530.000000    5206.750000
# 50%     47.0 -122.000000    1930.000000    7200.000000
# 75%     47.0 -122.000000    2322.500000    9450.000000
# max     47.0 -121.000000    3890.000000  247856.000000

# %%
Y.head()
# Out:
#     price
# 0  699000
# 1  285000
# 2  480000
# 3  359900
# 4  847000

# %%
# Here we add the target values as a last column, this is convenient to use seaborn
numerical_target = Y['price'] 

XY = X.assign(price=numerical_target.values)

# %% [markdown]
# Let's first display the distribution of the target column (price) using a boxplot.

# %%
var = 'bedrooms'
f, ax = plt.subplots(figsize=(14, 6))
fig = sns.boxplot(x=var, y='price', data=XY)
fig.axis(ymin=0, ymax=1500000);

# %% [markdown]
# we can also use a histogram for our target variable

# %%
var = 'grade'
f, ax = plt.subplots(figsize=(12, 6))
fig = sns.boxplot(x=var, y='price', data=XY)
fig.axis(ymin=0, ymax=1750000)
# Out:
# (-0.5, 8.5, 0, 1750000)

# %%
var = 'bathrooms'
f, ax = plt.subplots(figsize=(14, 6))
fig = sns.boxplot(x=var, y="price", data=XY)
fig.axis(ymin=0, ymax=3500000);

# %%
plt.hist(XY.price, bins = 25)
# Out:
# (array([  5.,  13.,  18.,  12.,   9.,   8.,   8.,   6.,   9.,   1.,   2.,
#           0.,   3.,   1.,   1.,   1.,   1.,   0.,   0.,   0.,   1.,   0.,
#           0.,   0.,   1.]),
#  array([  110000.,   201000.,   292000.,   383000.,   474000.,   565000.,
#           656000.,   747000.,   838000.,   929000.,  1020000.,  1111000.,
#          1202000.,  1293000.,  1384000.,  1475000.,  1566000.,  1657000.,
#          1748000.,  1839000.,  1930000.,  2021000.,  2112000.,  2203000.,
#          2294000.,  2385000.]),
#  <a list of 25 Patch objects>)

# %% [markdown]
# Immediately, we notice that the distribution is skewed towards cheaper homes. To make the distribution more symmetric, we can use its logarithm:

# %%
plt.hist(np.log(XY.price), bins = 25)
# Out:
# (array([  1.,   0.,   1.,   0.,   3.,   4.,   5.,   4.,   5.,  12.,   7.,
#           8.,   6.,   4.,   7.,  10.,   9.,   3.,   2.,   3.,   2.,   2.,
#           0.,   1.,   1.]),
#  array([ 11.60823564,  11.73129461,  11.85435357,  11.97741253,
#          12.10047149,  12.22353045,  12.34658941,  12.46964838,
#          12.59270734,  12.7157663 ,  12.83882526,  12.96188422,
#          13.08494318,  13.20800214,  13.33106111,  13.45412007,
#          13.57717903,  13.70023799,  13.82329695,  13.94635591,
#          14.06941487,  14.19247384,  14.3155328 ,  14.43859176,
#          14.56165072,  14.68470968]),
#  <a list of 25 Patch objects>)

# %%
sns.stripplot(x='bedrooms', y='price',data=XY)

# %% [markdown]
# The graph indicates that the relation of price with bedrooms. Price goes up with number of bedrooms upto 6 and then comes down as no of bedrooms increase.

# %%
sns.stripplot(x='grade', y='price',data=XY, size=5)

# %% [markdown]
# Price of the house is dependent on grade of the house, higher the grade higher the price.

# %%
df=XY
df['age_of_renov'] = 100
df.loc[df['yr_renovated'] != 0,'age_of_renov'] = 2015-df.loc[df['yr_renovated'] != 0,'yr_renovated']

sns.regplot(x='age_of_renov',y='price',data=XY)

# %% [markdown]
# the relation between the price and age of renovation

# %%
sns.regplot(x='sqft_living',y='price',data=XY)

# %%
sns.regplot(x='sqft_basement',y='price',data=XY)

# %%
sns.regplot(x='sqft_above',y='price',data=XY)

# %%
sns.set()
cols = ['price', 'sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bedrooms','bathrooms']
sns.pairplot(XY[cols], size = 2.5,  palette='afmhot')
plt.show();

# %% [markdown]
# # Building predictive models
# The initial classifier in your sandbox.

# %%
X = X.values
y=numerical_target 

X_test = X_test.values
y_test=Y_test['price']

X_valid = X_valid.values
y_valid=Y_valid['price']

from sklearn.base import BaseEstimator
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets, linear_model
from sklearn.tree import DecisionTreeRegressor

class Classifier(BaseEstimator):
    def __init__(self):
        self.clf = linear_model.LinearRegression()

    def fit(self, X, y):
        self.clf.fit(X, y)

    def predict(self, X):
        return self.clf.predict(X)

    def predict_proba(self, X):
        return self.clf.predict_proba(X)

# %%
from sklearn.cross_validation import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, mean_squared_error
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import KFold # import KFold
from numpy import zeros, mean

kf = KFold(n_splits=3,random_state=1) # Define the split - into 2 folds 
i=0
scores = zeros(3)

    
for idx_t, idx_v in kf.split(X):
    Xtr = X[idx_t]
    Ytr = y[idx_t]
   
    Xva = X[idx_v]
    Yva = y[idx_v]
    clf = Classifier()
    clf.fit(Xtr, Ytr)
    Y_predict = clf.predict(Xva)
    scores[i] =r2_score(Yva,Y_predict )
    print 'Fold', i+1, 'R2 score metric = ', scores[i]
    i=i+1
print 'Average score = ', mean(scores)
# Out:
# Fold 1 R2 score metric =  0.663806315496
# Fold 2 R2 score metric =  0.517664725775
# Fold 3 R2 score metric =  0.133393254025
# Average score =  0.438288098432

# %%
from sklearn.cross_validation import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score

# This will perform 2-fold cross-validation
# for 0.18 version or newer, use:
from sklearn.model_selection import cross_val_score

# for pre-0.18 versions of scikit, use:
from sklearn.cross_validation import cross_val_score


scores = cross_val_score(linear_model.LinearRegression(), X, y, cv=3)
print scores
# Out:
# [ 0.66380632  0.51766473  0.13339325]

# %%
outdir = 'sample_result_submission'

# %%
from model import model

# %%
M = model()
trained_model_name = model_dir + basename
M = M.load(trained_model_name)
# Out:
# Model reloaded from: sample_code_submission/houseprice_model.pickle

# %%
if not(M.is_trained):
    X_train = X
    Y_train = numerical_target
    M.fit(X_train, Y_train)  
Y_hat_train = M.predict(X) # Optional, not really needed to test on taining examples
Y_hat_valid = M.predict(X_valid)
Y_hat_test = M.predict(X_test)
# Out:
# PREDICT: dim(X)= [100, 18]
# PREDICT: dim(y)= [100, 1]
# PREDICT: dim(X)= [50, 18]
# PREDICT: dim(y)= [50, 1]
# PREDICT: dim(X)= [50, 18]
# PREDICT: dim(y)= [50, 1]

# %% [markdown]
# Save the trained model (will be ready to reload next time around) and save the prediction results:

# %%
M.save(trained_model_name)                 
result_name = 'sample_result_submission/' + basename
#import os
#os.write(result_name + '_valid.predict', Y_hat_valid)
#os.write(result_name + '_test.predict', Y_hat_test)
#!ls $result_name*

# %% [markdown]
# # Step 3: Making a submission
#
# ## Unit testing
#
# It is <b><span style="color:red">important that you test your submission files before submitting them</span></b>. All you have to do to make a submission is modify the file <code>model.py</code> in the <code>sample_code_submission/</code> directory, then run this test to make sure everything works fine. This is the actual program that will be run on the server to test your submission.

# %%
outdir = 'sample_result_submission'

# %%
# !python $problem_dir/ingestion.py $datadir $outdir $problem_dir $model_dir
# Out:
# Using input_dir: /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data
# Using output_dir: /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_result_submission
# Using program_dir: /Users/belrhalmia/Downloads/houseprice_starting_kit/ingestion_program
# Using submission_dir: /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_code_submission
#
# ========== Ingestion program version 6 ==========
#
# ************************************************
# ******** Processing dataset Houseprice ********
# ************************************************
# ========= Reading and converting data ==========
# Info file NOT found : /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data/houseprice_public.info
# ========= Reading /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data/houseprice_feat.type
# [+] Success in  0.00 sec
# ========= Reading /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data/houseprice_train.data
# [+] Success in  0.00 sec
# ========= Reading /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data/houseprice_train.solution
# [+] Success in  0.00 sec
# ========= Reading /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data/houseprice_valid.data
# [+] Success in  0.00 sec
# ========= Reading /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data/houseprice_test.data
# [+] Success in  0.00 sec
# DataManager : houseprice
# info:
# 	task = regression
# 	valid_num = 50
# 	has_categorical = 0
# 	feat_type = Mixed
# 	format = dense
# 	metric = r2_metric
# 	target_type = Numerical
# 	test_num = 50
# 	label_num = 0
# 	target_num = 1
# 	train_num = 100
# 	has_missing = 0
# 	usage = No Info File
# 	feat_num = 18
# 	time_budget = 600
# 	is_sparse = 0
# 	name = houseprice
# data:
# 	X_train = array(100, 18)
# 	Y_train = array(100,)
# 	X_valid = array(50, 18)
# 	X_test = array(50, 18)
# feat_type:	array(18,)
# feat_idx:	array(18,)
#
# [+] Size of uploaded data  72.00 bytes
# [+] Cumulated time budget (all tasks so far)  600.00 sec
# [+] Time budget for this task 600.00 sec
# [+] Remaining time after reading data 600.00 sec
# ======== Creating model ==========
# **********************************************************
# ****** Attempting to reload model to avoid training ******
# **********************************************************
# Model reloaded from: /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_code_submission/houseprice_model.pickle
# [+] Model reloaded, no need to train!
# PREDICT: dim(X)= [100, 18]
# PREDICT: dim(y)= [100, 1]
# PREDICT: dim(X)= [50, 18]
# PREDICT: dim(y)= [50, 1]
# PREDICT: dim(X)= [50, 18]
# PREDICT: dim(y)= [50, 1]
# [+] Prediction success, time spent so far  0.00 sec
# ======== Saving results to: /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_result_submission
# [+] Results saved, time spent so far  0.00 sec
# [+] End cycle, time left 600.00 sec
# [+] Done
# [+] Overall time spent  1.30 sec ::  Overall time budget 600.00 sec

# %% [markdown]
# # Making submission

# %%
outdir = 'sample_result_submission'
# !python2 $problem_dir/ingestion.py $datadir $outdir $problem_dir $model_dir
# Out:
# Using input_dir: /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data
# Using output_dir: /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_result_submission
# Using program_dir: /Users/belrhalmia/Downloads/houseprice_starting_kit/ingestion_program
# Using submission_dir: /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_code_submission
#
# ========== Ingestion program version 6 ==========
#
# ************************************************
# ******** Processing dataset Houseprice ********
# ************************************************
# ========= Reading and converting data ==========
# Info file NOT found : /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data/houseprice_public.info
# ========= Reading /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data/houseprice_feat.type
# [+] Success in  0.00 sec
# ========= Reading /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data/houseprice_train.data
# [+] Success in  0.00 sec
# ========= Reading /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data/houseprice_train.solution
# [+] Success in  0.00 sec
# ========= Reading /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data/houseprice_valid.data
# [+] Success in  0.00 sec
# ========= Reading /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_data/houseprice_test.data
# [+] Success in  0.00 sec
# DataManager : houseprice
# info:
# 	task = regression
# 	valid_num = 50
# 	has_categorical = 0
# 	feat_type = Mixed
# 	format = dense
# 	metric = r2_metric
# 	target_type = Numerical
# 	test_num = 50
# 	label_num = 0
# 	target_num = 1
# 	train_num = 100
# 	has_missing = 0
# 	usage = No Info File
# 	feat_num = 18
# 	time_budget = 600
# 	is_sparse = 0
# 	name = houseprice
# data:
# 	X_train = array(100, 18)
# 	Y_train = array(100,)
# 	X_valid = array(50, 18)
# 	X_test = array(50, 18)
# feat_type:	array(18,)
# feat_idx:	array(18,)
#
# [+] Size of uploaded data  72.00 bytes
# [+] Cumulated time budget (all tasks so far)  600.00 sec
# [+] Time budget for this task 600.00 sec
# [+] Remaining time after reading data 600.00 sec
# ======== Creating model ==========
# **********************************************************
# ****** Attempting to reload model to avoid training ******
# **********************************************************
# Model reloaded from: /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_code_submission/houseprice_model.pickle
# [+] Model reloaded, no need to train!
# PREDICT: dim(X)= [100, 18]
# PREDICT: dim(y)= [100, 1]
# PREDICT: dim(X)= [50, 18]
# PREDICT: dim(y)= [50, 1]
# PREDICT: dim(X)= [50, 18]
# PREDICT: dim(y)= [50, 1]
# [+] Prediction success, time spent so far  0.00 sec
# ======== Saving results to: /Users/belrhalmia/Downloads/houseprice_starting_kit/sample_result_submission
# [+] Results saved, time spent so far  0.01 sec
# [+] End cycle, time left 599.99 sec
# [+] Done
# [+] Overall time spent  1.31 sec ::  Overall time budget 600.00 sec
